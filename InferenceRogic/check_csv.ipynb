# %%
import pandas as pd

pd.set_option("display.max_columns", None)
train_data = "test.csv"

train_df = pd.read_csv(train_data)
train_df.head()
# Out:
#                                                 body  coediting  \
# 0  # はじめに\n\nMacBookを選ぶ際は、メモリ 8GB、SSD 512GB以上を選びま...      False
# 1  ### Projevt Euler Ploblem 12 (プロジェクトオイラー１２)\n#...      False
# 2  初心者です。  \nAndroidStudioでMaterial3なカルーセルを作りたあああ...      False
# 3  Buy verified Binance accounts to ensure a secu...      False
# 4  7M CN MA CAO - Trang cung cấp tỷ số trực tuyến...      False
#
#    comments_count  likes_count  stocks_count tags.0.name    tags.1.name  \
# 0               0            0             0         Mac         Docker
# 1               0            0             0         初心者   ProjectEuler
# 2               0            0             0        Java  AndroidStudio
# 3               0            0             0         buy        binance
# 4               0            0             0   7mcnmacao            NaN
#
#                                                title  \
# 0                          Macのストレージは512GB以上を買おうと言う話
# ...
